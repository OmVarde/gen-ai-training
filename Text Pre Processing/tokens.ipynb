# %%
corpus = ''' Hello Welcome, to the Krish Naik's NLP turtorials.
PLease watch the entire course! to become expert in NLP.
'''

# %%
print(corpus)
# Out:
#  Hello Welcome, to the Krish Naik's NLP turtorials.
# PLease watch the entire course! to become expert in NLP.

# %%
## tokenization
## sentence --> paragraphs

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\varde\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\varde\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
for i in documents:
    print(i)
# Out:
# ['Hello', 'Welcome', ',', 'to', 'the', 'Krish', 'Naik', "'s", 'NLP', 'turtorials', '.']
# ['PLease', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'the',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'turtorials',
#  '.',
#  'PLease',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for i in documents:
    print(word_tokenize(i))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'the', 'Krish', 'Naik', "'s", 'NLP', 'turtorials', '.']
# ['PLease', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'the',
#  'Krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'turtorials',
#  '.',
#  'PLease',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'the',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'turtorials.',
#  'PLease',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
